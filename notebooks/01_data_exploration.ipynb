# %% [markdown]
# # Data Exploration
#
# This notebook explores the datasets used for ML model training and monitoring.
#
# ## Objectives:
# - Load and explore Adult Income dataset
# - Analyze feature distributions
# - Check for missing values and data quality
# - Explore class balance
# - Visualize relationships between features

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.load_data import load_adult_data, generate_synthetic_data
from src.utils.logger import logger

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

logger.info("Starting data exploration...")
